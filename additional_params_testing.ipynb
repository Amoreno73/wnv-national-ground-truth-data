# %% [markdown]
# ### Additional Params:
# 1. Population density
# 2. Urban-Suburban-Rural
# 3. Wetland
# 4. distance to water bodies
# 5. Bid Migration Route map

# %% [markdown]
# #### 1. Population Density:
#
# * Calculated as ->  $\text{Density} = \frac{\text{County Population}}{\text{Area in } m^2}$

# %% [markdown]
# #### 2. Urban-Suburban-Rural NDVI:
#
# * https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MCD12Q1
#   * LC_Type1 value 13 -> "Urban and Built-up Lands: at least 30% impervious surface area including building materials, asphalt and vehicles."

# %% [markdown]
# #### 3. Wetlands:
#
# * https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MCD12Q1
#   * LC_Prop1 value 11 -> "Permanent Wetlands: permanently inundated lands with 30-60% water cover and >10% vegetated cover."
#   * LC_Prop3 value 27 -> "Woody Wetlands: shrub and tree cover >10% (>1m). Permanently or seasonally inundated."
#   * LC_Prop3 value 50 -> "Herbaceous Wetlands: dominated by herbaceous annuals (<2m) >10% cover. Permanently or seasonally inundated."

# %% [markdown]
# #### 4. Distance to waterbody:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 1. Population Density:
#
# * Calculated as $Density = \frac{\text{County Population}}{\text{Area in } m^2}$
